# %%
# Utilize, três funções de módulos nativos do python
# Link de módulos nativos: https://docs.python.org/3/py-modindex.html
# Caso queria uma dica rápida, utilize três função do módulo math
# Link do módulo math: https://docs.python.org/3/library/math.html#module-math

import math as m

print (m.gcd(7,14),'/',m.sqrt(9),'/',m.pi)
# Out:
# 7 / 3.0 / 3.141592653589793

# %%
# Utilize, uma função de um módulo disponibilizado pelo pip
# Link de módulos do pip: https://pypi.org/
# Caso queria uma dica rápida, utilize a função plot do matplotlib
# Link da função plot: https://matplotlib.org/3.2.2/api/_as_gen/matplotlib.pyplot.plot.html

import matplotlib.pyplot as lib

# %matplotlib inline

lib.plot([1,10,2,9,3,8,4,7,5,6])
